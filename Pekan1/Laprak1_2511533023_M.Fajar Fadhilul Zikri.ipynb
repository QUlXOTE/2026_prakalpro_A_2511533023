# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMROGRAMAN**
#
# ***“Pengenalan python, VScode, dan koneksi ke github”***
#
# **Disusun Oleh :**
#
# **M.Fajar Fadhilul Zikri**
#
# **2511533023**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Avero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum ... yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma dan pemograman. Praktikum ini berfokus pada pembahasan Pekan 1: Pengenalan python, VScode, dan koneksi ke github
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Pada saat ini di industri teknologi banyak programer menggunakan bahasa python sehingga  pada saat ini python menjadi bahasa yang paling banyak di ajarkan di tingkat sekolah sampai perkuliahan alasan kenapa python begitu populer terletak pada kepraktisan nya jika di bandingkan dengan bahasa pemograman lain seperti assembly,c,c++,Java,dll
#
# ## 1.2 Tujuan
# 1. Mengenal bahasa pemograman python
# 2. Mampu membuat program sederhana
# 3. Menghubungkan Vscode ke github
#
# ## 1.3 Manfaat
# 1. Mampu membuat dan mengaplikasikan program python
# 2. Dapat mehamahami proses push project ke github

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
#
# 1. (#) untuk komen single line
# 2. """ komen multi baris
# 3. print(" ") untuk mencetak value didalam(" ")
# 4. print() untukmencetak baris kosong

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "program1_2511533023"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# program pertama
"""
komentar
dua baris pertama
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("Program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ ///\\\\\\")
print("program ini dibuat oleh" + "dibuat oleh a\n " + "M.Fajar fadhilul zikri dan 251153302")
# Out:
# Hello World
#
# Program ini menghasilkan
# Empat baris output
# / \ // \\ ///\\\
# program ini dibuat olehdibuat oleh a
#  M.Fajar fadhilul zikri dan 251153302

# %% [markdown]
# **Penjelasan :**
# 1. Baris pertama sebagai komentar (#)
# 2. Baris kedua komentar multi baris untuk memberikan penjelasan tanpa di eksekusi oleh program (""")
# 3. Bagian ketiga dari hello world sampai M.Fajar Fadhilu Zikri dan 2511533023 merupakan type data string karena di python (" ") dikenali sebagai string dan 2511533023 yang seharusnya integer dikenali oleh python sebagai string karena berada dalam (" ") dan perintah print(" ") berfungsi untuk menampilkn teks yang berupa string sementara print() berfungsi untuk mencetak baris kosong.

# %% [markdown]
# **Tugas Alpro1**

# %%
# Modul pekan3 (di Python cukup menggunakan file/folder)

def main():
    # Input data dari pengguna
    A1_3023 = int(input("Input angka-1: "))
    A2_3023 = int(input("Input angka-2: "))

    # Operator Penjumlahan
    print("operator Penjumlahan")
    hasil_3023 = A1_3023 + A2_3023
    print("Hasil =", hasil_3023)

    # Operator Pengurangan
    print("operator Pengurangan")
    hasil_3023 = A1_3023 - A2_3023
    print("Hasil =", hasil_3023)

    # Operator Perkalian
    print("operator Perkalian")
    hasil_3023 = A1_3023 * A2_3023
    print("Hasil =", hasil_3023)

    # Operator Hasil Bagi (pembagian bulat)
    print("operator hasil bagi")
    hasil_3023 = A1_3023 // A2_3023  # Gunakan // untuk pembagian bulat seperti pada tipe data 'int' di Java
    print("Hasil =", hasil_3023)

    # Operator Sisa Bagi (Modulus)
    print("operator sisa bagi")
    hasil_3023 = A1_3023 % A2_3023
    print("Hasil =", hasil_3023)


if __name__ == "__main__":
    main()
# Out:
# operator Penjumlahan
# Hasil = 7
# operator Pengurangan
# Hasil = -3
# operator Perkalian
# Hasil = 10
# operator hasil bagi
# Hasil = 0
# operator sisa bagi
# Hasil = 2

# %% [markdown]
# **Penjelasan Program : **Program ini berfungsi untuk menerima dua masukan angka bulat dari pengguna, kemudian melakukan dan menampilkan hasil dari 5 operasi aritmatika dasar: **penjumlahan (+)**, **pengurangan (-)**, **perkalian (*)**, **hasil bagi bulat (//)**, dan **sisa bagi/modulus (%)**.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, saya jadi sedikit lebih memahami tentang bahasa pemrograman python dimana # sebagai tanda untuk single line komentar dan """ untuk komentar multi baris dan juga saya belajar sedikit type data yang pada praktikum ini merupakan type data string meskipun ada angka didalam nya hal ini terjadi karena angka tsb berada dalam " " yang mana python mengenali nya sebagai string bukan integer dan untuk print gunanya untuk menampilkan teks yang berada di dalam (" ") jika print() perintah ini untuk mencetak baris kosong sehingga output yang dihasilkan dapat dipisah seperti hasil output program yang saya bikin selama praktikum ini berlangsung.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] https://learnpython.org/
#
# [2] https://www.w3schools.com/python/
